# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
#load dataset
df=sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
#histogram
df.hist(figsize=(10,8),bins=15,color='skyblue',edgecolor='black')
plt.suptitle("Feature Distributionv (Histogram)-Iris Dataset", fontsize=14)
plt.tight_layout()
plt.show()

# %%
#box plot
plt.figure(figsize=(12,6))
numeric_columns =df.select_dtypes(include='number').columns
for i,columns in enumerate(numeric_columns):
    plt.subplot(1,len(numeric_columns),i+1)
    sns.boxplot(y=df[column],color='lightgreen')
    plt.title(column)
plt.suptitle("Box Plots of Numeric Features -Iris Dataset",fontsize=14)
plt.tight_layout(rect=[0,0.03,1,0.95])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 6
#       4 for i,columns in enumerate(numeric_columns):
#       5     plt.subplot(1,len(numeric_columns),i+1)
# ----> 6     sns.boxplot(y=df[column],color='lightgreen')
#       7     plt.title(column)
#       8 plt.suptitle("Box Plots of Numeric Features -Iris Dataset",fontsize=14)
#
# NameError: name 'column' is not defined
