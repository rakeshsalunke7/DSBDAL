# %%
import pandas as pd

# %%
dt=pd.read_csv('retail_store_inventory.csv')

# %%
dt
# Out:
#              Date Store ID Product ID     Category Region  Inventory Level  \
# 0      2022-01-01     S001      P0001    Groceries  North              231
# 1      2022-01-01     S001      P0002         Toys  South              204
# 2      2022-01-01     S001      P0003         Toys   West              102
# 3      2022-01-01     S001      P0004         Toys  North              469
# 4      2022-01-01     S001      P0005  Electronics   East              166
# ...           ...      ...        ...          ...    ...              ...
# 73095  2024-01-01     S005      P0016    Furniture   East               96
# 73096  2024-01-01     S005      P0017         Toys  North              313
# 73097  2024-01-01     S005      P0018     Clothing   West              278
# 73098  2024-01-01     S005      P0019         Toys   East              374
# 73099  2024-01-01     S005      P0020    Groceries   East              117
#
# ...

# %%
dt.dtypes
# Out:
# Date                   object
# Store ID               object
# Product ID             object
# Category               object
# Region                 object
# Inventory Level         int64
# Units Sold              int64
# Units Ordered           int64
# Demand Forecast       float64
# Price                 float64
# Discount                int64
# Weather Condition      object
# Holiday/Promotion       int64
# Competitor Pricing    float64
# Seasonality            object
# dtype: object

# %%
dt.columns
# Out:
# Index(['Date', 'Store ID', 'Product ID', 'Category', 'Region',
#        'Inventory Level', 'Units Sold', 'Units Ordered', 'Demand Forecast',
#        'Price', 'Discount', 'Weather Condition', 'Holiday/Promotion',
#        'Competitor Pricing', 'Seasonality'],
#       dtype='object')

# %%
dt.describe
# Out:
# <bound method NDFrame.describe of              Date Store ID Product ID     Category Region  Inventory Level  \
# 0      2022-01-01     S001      P0001    Groceries  North              231
# 1      2022-01-01     S001      P0002         Toys  South              204
# 2      2022-01-01     S001      P0003         Toys   West              102
# 3      2022-01-01     S001      P0004         Toys  North              469
# 4      2022-01-01     S001      P0005  Electronics   East              166
# ...           ...      ...        ...          ...    ...              ...
# 73095  2024-01-01     S005      P0016    Furniture   East               96
# 73096  2024-01-01     S005      P0017         Toys  North              313
# 73097  2024-01-01     S005      P0018     Clothing   West              278
# 73098  2024-01-01     S005      P0019         Toys   East              374
# 73099  2024-01-01     S005      P0020    Groceries   East              117
#
# ...

# %%
dt.shape
# Out:
# (73100, 15)

# %%
dt.tail(7)
# Out:
#              Date Store ID Product ID   Category Region  Inventory Level  \
# 73093  2024-01-01     S005      P0014       Toys   West              328
# 73094  2024-01-01     S005      P0015  Furniture  North              408
# 73095  2024-01-01     S005      P0016  Furniture   East               96
# 73096  2024-01-01     S005      P0017       Toys  North              313
# 73097  2024-01-01     S005      P0018   Clothing   West              278
# 73098  2024-01-01     S005      P0019       Toys   East              374
# 73099  2024-01-01     S005      P0020  Groceries   East              117
#
#        Units Sold  Units Ordered  Demand Forecast  Price  Discount  \
# 73093         190             43           183.97  66.50         0
# 73094         323             92           336.64  83.26         0
# 73095           8            127            18.46  73.73        20
# 73096          51            101            48.43  82.57        10
# ...

# %%
dt.head(5)
# Out:
#          Date Store ID Product ID     Category Region  Inventory Level  \
# 0  2022-01-01     S001      P0001    Groceries  North              231
# 1  2022-01-01     S001      P0002         Toys  South              204
# 2  2022-01-01     S001      P0003         Toys   West              102
# 3  2022-01-01     S001      P0004         Toys  North              469
# 4  2022-01-01     S001      P0005  Electronics   East              166
#
#    Units Sold  Units Ordered  Demand Forecast  Price  Discount  \
# 0         127             55           135.47  33.50        20
# 1         150             66           144.04  63.01        20
# 2          65             51            74.02  27.99        10
# 3          61            164            62.18  32.72        10
# 4          14            135             9.26  73.64         0
#
#   Weather Condition  Holiday/Promotion  Competitor Pricing Seasonality
# 0             Rainy                  0               29.69      Autumn
# ...

# %%
dt.index
# Out:
# RangeIndex(start=0, stop=73100, step=1)

# %%
dt.sort_values(by="Region")
# Out:
#              Date Store ID Product ID   Category Region  Inventory Level  \
# 73099  2024-01-01     S005      P0020  Groceries   East              117
# 47103  2023-04-17     S001      P0004   Clothing   East              450
# 47106  2023-04-17     S001      P0007   Clothing   East              301
# 47115  2023-04-17     S001      P0016       Toys   East              243
# 47116  2023-04-17     S001      P0017       Toys   East               81
# ...           ...      ...        ...        ...    ...              ...
# 15537  2022-06-05     S002      P0018  Groceries   West              418
# 49718  2023-05-13     S001      P0019   Clothing   West              180
# 15539  2022-06-05     S002      P0020  Furniture   West              107
# 49746  2023-05-13     S003      P0007   Clothing   West              160
# 14606  2022-05-27     S001      P0007   Clothing   West              441
#
#        Units Sold  Units Ordered  Demand Forecast  Price  Discount  \
# ...

# %%
dt.iloc[:3 , :5]
# Out:
#          Date Store ID Product ID   Category Region
# 0  2022-01-01     S001      P0001  Groceries  North
# 1  2022-01-01     S001      P0002       Toys  South
# 2  2022-01-01     S001      P0003       Toys   West

# %%
dt.iloc[:4, :]
# Out:
#          Date Store ID Product ID   Category Region  Inventory Level  \
# 0  2022-01-01     S001      P0001  Groceries  North              231
# 1  2022-01-01     S001      P0002       Toys  South              204
# 2  2022-01-01     S001      P0003       Toys   West              102
# 3  2022-01-01     S001      P0004       Toys  North              469
#
#    Units Sold  Units Ordered  Demand Forecast  Price  Discount  \
# 0         127             55           135.47  33.50        20
# 1         150             66           144.04  63.01        20
# 2          65             51            74.02  27.99        10
# 3          61            164            62.18  32.72        10
#
#   Weather Condition  Holiday/Promotion  Competitor Pricing Seasonality
# 0             Rainy                  0               29.69      Autumn
# 1             Sunny                  0               66.16      Autumn
# 2             Sunny                  1               31.32      Summer
# ...

# %%
dt.iloc[:, :5]
# Out:
#              Date Store ID Product ID     Category Region
# 0      2022-01-01     S001      P0001    Groceries  North
# 1      2022-01-01     S001      P0002         Toys  South
# 2      2022-01-01     S001      P0003         Toys   West
# 3      2022-01-01     S001      P0004         Toys  North
# 4      2022-01-01     S001      P0005  Electronics   East
# ...           ...      ...        ...          ...    ...
# 73095  2024-01-01     S005      P0016    Furniture   East
# 73096  2024-01-01     S005      P0017         Toys  North
# 73097  2024-01-01     S005      P0018     Clothing   West
# 73098  2024-01-01     S005      P0019         Toys   East
# 73099  2024-01-01     S005      P0020    Groceries   East
#
# [73100 rows x 5 columns]

# %%
dt.iloc[[1, 2,4], [0, 2]]
# Out:
#          Date Product ID
# 1  2022-01-01      P0002
# 2  2022-01-01      P0003
# 4  2022-01-01      P0005

# %%
dt.iloc[1, 1]
# Out:
# 'S001'

# %%
dt.iloc[3:5, 0:2]
# Out:
#          Date Store ID
# 3  2022-01-01     S001
# 4  2022-01-01     S001

# %%
dt.ProductId.values
